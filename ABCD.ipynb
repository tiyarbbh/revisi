# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['Price_in_euros'] = df['Price_in_euros'] * 16000

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.rename(columns={'Price_in_euros': 'Price_in_IDR'}, inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['Price_in_IDR'] = df['Price_in_IDR'].map('{:,.0f}'.format)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_in_IDR      1303 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 132.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_in_IDR        0
# dtype: int64

# %%
# Remove GB dan KG pada kolom ram dan weight
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight Price_in_IDR
# 0  Intel Iris Plus Graphics 640  macOS   1.37   21,435,040
# ...

# %%
# Convert tipe data kolom Ram dan Weight menjadi int32 dan float32
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_in_IDR      1303 non-null   object
# dtypes: float32(1), float64(1), int32(1), object(9)
# memory usage: 112.1+ KB

# %%
df['Price_in_IDR'] = df['Price_in_IDR'].replace(',', '', regex=True).astype(float)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_in_IDR
# 0  Intel Iris Plus Graphics 640  macOS    1.37    21435040.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_in_IDR      1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(8)
# memory usage: 112.1+ KB

# %%
df.drop(columns=['Product'],inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Analisis Kolom Price
sns.distplot(df['Price_in_IDR'])
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\3067473438.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_in_IDR'])
# <Axes: xlabel='Price_in_IDR', ylabel='Density'>

# %%
# Company Analysis
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Average price value of each brands
sns.barplot(x=df['Company'],y=df['Price_in_IDR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# TypeName Analysis
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Average values of each type of laptops
sns.barplot(x=df['TypeName'],y=df['Price_in_IDR'])
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'], y=df['Price_in_IDR'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price_in_IDR'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
# Kolom baru dengan informasi touchscreen
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
# Menampilkan 5 data random
df.sample(5)
# Out:
#     Company   TypeName  Inches             ScreenResolution  \
# 86       HP  Ultrabook    15.6  IPS Panel Full HD 1920x1080
# 73      MSI     Gaming    17.3            Full HD 1920x1080
# 464  Lenovo   Notebook    15.6            Full HD 1920x1080
# 162    Dell   Notebook    15.6            Full HD 1920x1080
# 617      HP  Ultrabook    15.6            Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 86    Intel Core i7 8550U 1.8GHz    8             256GB SSD
# 73   Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 464  Intel Core i7 7820HQ 2.9GHz    8             256GB SSD
# 162   Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 617   Intel Core i7 7500U 2.7GHz    8             512GB SSD
#
#                           Gpu       OpSys  Weight  Price_in_IDR  Touchscreen
# 86   Nvidia GeForce GTX 940MX  Windows 10    1.83    11184000.0            0
# 73    Nvidia GeForce GTX 1050  Windows 10    2.70    17520000.0            0
# ...

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price_in_IDR'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price_in_IDR'>

# %%
# Kolom baru dengan informasi IPS
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
# Menampilkan 5 data random
df.sample(5)
# Out:
#     Company            TypeName  Inches  \
# 28     Dell           Ultrabook    15.6
# 620      HP            Notebook    14.0
# 121     MSI              Gaming    15.6
# 933  Lenovo  2 in 1 Convertible    13.3
# 929      HP            Notebook    14.0
#
#                                ScreenResolution                          Cpu  \
# 28                            Full HD 1920x1080   Intel Core i7 8650U 1.9GHz
# 620                                    1366x768   Intel Core i5 7300U 2.6GHz
# 121                           Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 933  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6560U 2.2GHz
# 929                                    1366x768   Intel Core i5 6200U 2.3GHz
#
#      Ram                  Memory                      Gpu       OpSys  Weight  \
# 28     8  256GB SSD +  256GB SSD   Intel UHD Graphics 620  Windows 10    1.88
# 620    8               256GB SSD    Intel HD Graphics 620  Windows 10    2.31
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ips'],y=df['Price_in_IDR'])
# Harga laptop dengan IPS lebih mahal
# Out:
# <Axes: xlabel='Ips', ylabel='Price_in_IDR'>

# %%
# Kolom baru menampilkan Screen Resolution vertikal dan horizontal
new = df['ScreenResolution'].str.split('x', n=1, expand=True)
df['X_res'] = new[0]
df['Y_res'] = new[1]
df.sample(5)
# Out:
#      Company   TypeName  Inches                    ScreenResolution  \
# 669     Acer   Notebook    15.6                            1366x768
# 17     Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 193   Lenovo   Notebook    17.3                            1600x900
# 1065    Dell  Ultrabook    13.3                   Full HD 1920x1080
# 137     Asus     Gaming    17.3                   Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 669      Intel Core i3 6006U 2GHz    4             128GB SSD
# 17           Intel Core i7 2.9GHz   16             512GB SSD
# 193    Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 1065   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 137   Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight  Price_in_IDR  Touchscreen  \
# 669     Intel HD Graphics 520       Linux    2.10     6592000.0            0
# ...

# %%
# Membersihkan data kolom X_res
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'\d+\.?\d+').apply(lambda x:x[0])
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_in_IDR  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37    21435040.0            0
# 1        Intel HD Graphics 6000  macOS    1.34    14383040.0            0
# ...

# %%
# Mengubah data type menjadi int
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price_in_IDR      1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
# Analisis korelasi
df.corr()['Price_in_IDR']
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\4089169661.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price_in_IDR']
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# Price_in_IDR    1.000000
# Touchscreen     0.191226
# Ips             0.252208
# X_res           0.556529
# Y_res           0.552809
# Name: Price_in_IDR, dtype: float64

# %%
# Membuat variabel ppi (pixel per inch)
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2)) ** 0.5/df['Inches']).astype('float')
df.corr()['Price_in_IDR']
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\3088548974.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price_in_IDR']
# Inches          0.068197
# Ram             0.743007
# Weight          0.210370
# Price_in_IDR    1.000000
# Touchscreen     0.191226
# Ips             0.252208
# X_res           0.556529
# Y_res           0.552809
# ppi             0.473487
# Name: Price_in_IDR, dtype: float64

# %%
# Menghapus kolom ScreenResolution
df.drop(columns=['ScreenResolution'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_in_IDR  Touchscreen  Ips  X_res  Y_res         ppi
# 0    21435040.0            0    1   2560   1600  226.983005
# 1    14383040.0            0    0   1440    900  127.677940
# ...

# %%
# Menghapus kolom Inches, X_res, Y_res
df.drop(columns=['Inches', 'X_res', 'Y_res'],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_in_IDR  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37    21435040.0            0
# 1        Intel HD Graphics 6000  macOS    1.34    14383040.0            0
# 2         Intel HD Graphics 620  No OS    1.86     9200000.0            0
# 3            AMD Radeon Pro 455  macOS    1.83    40599200.0            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37    28857600.0            0
#
#    Ips         ppi
# 0    1  226.983005
# 1    0  127.677940
# ...

# %%
# Menambah kolom baru CPU name
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_in_IDR  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37    21435040.0            0
# 1        Intel HD Graphics 6000  macOS    1.34    14383040.0            0
# 2         Intel HD Graphics 620  No OS    1.86     9200000.0            0
# 3            AMD Radeon Pro 455  macOS    1.83    40599200.0            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37    28857600.0            0
#
#    Ips         ppi       Cpu Name
# 0    1  226.983005  Intel Core i5
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
# Memilah jenis processor laptop
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'
        
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_in_IDR  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37    21435040.0            0
# 1        Intel HD Graphics 6000  macOS    1.34    14383040.0            0
# 2         Intel HD Graphics 620  No OS    1.86     9200000.0            0
# 3            AMD Radeon Pro 455  macOS    1.83    40599200.0            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37    28857600.0            0
#
#    Ips         ppi       Cpu Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price_in_IDR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Menghapus kolom Cpu dan Cpu Name
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight  Price_in_IDR  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37    21435040.0            0    1  226.983005  Intel Core i5
# 1  macOS    1.34    14383040.0            0    0  127.677940  Intel Core i5
# 2  No OS    1.86     9200000.0            0    0  141.211998  Intel Core i5
# 3  macOS    1.83    40599200.0            0    1  220.534624  Intel Core i7
# 4  macOS    1.37    28857600.0            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price_in_IDR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# Memilah jenis Memory laptop
df['Memory'] = df['Memory'].astype(str).replace('\.0','', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 
        'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 
        'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\642414485.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\642414485.py:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram               Memory  \
# 294   Lenovo            Notebook    8              256 SSD
# 221   Lenovo  2 in 1 Convertible    8              256 SSD
# 1014      HP            Notebook    4              500 HDD
# 211     Asus              Gaming   16  256 SSD +  1000 HDD
# 568   Lenovo            Notebook    4              500 HDD
#
#                           Gpu       OpSys  Weight  Price_in_IDR  Touchscreen  \
# 294    Intel UHD Graphics 620  Windows 10    2.05    11824000.0            0
# 221    Intel UHD Graphics 620  Windows 10    1.74    14384000.0            0
# 1014    Intel HD Graphics 620  Windows 10    1.49    12800000.0            0
# 211   Nvidia GeForce GTX 1050  Windows 10    2.90    22512000.0            0
# 568     Intel HD Graphics 505  Windows 10    2.20     5504000.0            0
#
#       Ips         ppi              Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
# Menghapus kolom Memory
df.drop(columns=['Memory'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_in_IDR  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0    21435040.0            0    1  226.983005  Intel Core i5    0  128
# 1    14383040.0            0    0  127.677940  Intel Core i5    0    0
# 2     9200000.0            0    0  141.211998  Intel Core i5    0  256
# 3    40599200.0            0    1  220.534624  Intel Core i7    0  512
# 4    28857600.0            0    1  226.983005  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# 2       0              0
# ...

# %%
# Korelasi terhadap harga
df.corr()['Price_in_IDR']
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\3000622668.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price_in_IDR']
# Ram              0.743007
# Weight           0.210370
# Price_in_IDR     1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price_in_IDR, dtype: float64

# %%
# Menghapus kolom Hybrid dan Flash Storage
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_in_IDR  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0    21435040.0            0    1  226.983005  Intel Core i5    0  128
# 1    14383040.0            0    0  127.677940  Intel Core i5    0    0
# 2     9200000.0            0    0  141.211998  Intel Core i5    0  256
# 3    40599200.0            0    1  220.534624  Intel Core i7    0  512
# 4    28857600.0            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_in_IDR  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0    21435040.0            0    1  226.983005  Intel Core i5    0  128
# 1    14383040.0            0    0  127.677940  Intel Core i5    0    0
# 2     9200000.0            0    0  141.211998  Intel Core i5    0  256
# 3    40599200.0            0    1  220.534624  Intel Core i7    0  512
# 4    28857600.0            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
sns.barplot(x=df['Gpu Brand'],y=df['Price_in_IDR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Menghapus kolom Gpu
df.drop(columns=['Gpu'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight  Price_in_IDR  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37    21435040.0            0    1
# 1   Apple  Ultrabook    8  macOS    1.34    14383040.0            0    0
# 2      HP   Notebook    8  No OS    1.86     9200000.0            0    0
# 3   Apple  Ultrabook   16  macOS    1.83    40599200.0            0    1
# 4   Apple  Ultrabook    8  macOS    1.37    28857600.0            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price_in_IDR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Memilah jenis operation system
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'
    
df['os'] = df['OpSys'].apply(cat_os)
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight  Price_in_IDR  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37    21435040.0            0    1
# 1   Apple  Ultrabook    8  macOS    1.34    14383040.0            0    0
# 2      HP   Notebook    8  No OS    1.86     9200000.0            0    0
# 3   Apple  Ultrabook   16  macOS    1.83    40599200.0            0    1
# 4   Apple  Ultrabook    8  macOS    1.37    28857600.0            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu Brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
# Menampilkan barplot operation system terhadap harga laptop
sns.barplot(x=df['os'],y=df['Price_in_IDR'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight  Price_in_IDR  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37    21435040.0            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34    14383040.0            0    0  127.677940
# 2      HP   Notebook    8    1.86     9200000.0            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83    40599200.0            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37    28857600.0            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu Brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price_in_IDR'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price_in_IDR'>

# %%
# Korelasi setelah data dibersihkan/dirapikan terhadap harga laptop
df.corr()['Price_in_IDR']
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\2449720038.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price_in_IDR']
# Ram             0.743007
# Weight          0.210370
# Price_in_IDR    1.000000
# Touchscreen     0.191226
# Ips             0.252208
# ppi             0.473487
# HDD            -0.096441
# SSD             0.670799
# Name: Price_in_IDR, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.distplot(np.log(df['Price_in_IDR']))
# Out:
# C:\Users\tiyar\AppData\Local\Temp\ipykernel_18420\2392925574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price_in_IDR']))
# <Axes: xlabel='Price_in_IDR', ylabel='Density'>

# %%
# Menghapus kolom harga
X = df.drop(columns=['Price_in_IDR'])
y = np.log(df['Price_in_IDR'])
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       16.880538
# 1       16.481560
# 2       16.034714
# 3       17.519259
# 4       17.177884
#           ...
# 1298    16.138682
# 1299    16.992897
# 1300    15.114066
# 1301    16.318912
# 1302    15.591141
# Name: Price_in_IDR, Length: 1303, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 699        HP            Notebook    4    2.10            0    1  141.211998
# 419    Lenovo           Ultrabook    8    1.75            0    1  157.350512
# 997      Acer            Notebook    4    2.40            0    0  100.454670
# 502    Lenovo  2 in 1 Convertible    8    1.40            1    1  158.482530
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1192       HP            Notebook    4    1.86            0    0  100.454670
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8244080785410999
# MAE 0.20979730698405324
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8226461848784257
# MAE 0.21010691414392915
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.823513837964237
# MAE 0.21089837837677725
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.831737961663366
# MAE 0.19351902141203867

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8311898530763326
# MAE 0.19227981986477558
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8545821799140763
# MAE 0.18959358914413071

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8876443042370024
# MAE 0.15800191516639048

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7930480634279871
# MAE 0.2299442782814378

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\tiyar\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8885859455038225
# MAE 0.1631670689154083

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight  Price_in_IDR  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37    21435040.0            0    1
# 1      Apple           Ultrabook    8    1.34    14383040.0            0    0
# 2         HP            Notebook    8    1.86     9200000.0            0    0
# 3      Apple           Ultrabook   16    1.83    40599200.0            0    1
# 4      Apple           Ultrabook    8    1.37    28857600.0            0    1
# ...      ...                 ...  ...     ...           ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80    10208000.0            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30    23984000.0            1    1
# 1300  Lenovo            Notebook    2    1.50     3664000.0            0    0
# 1301      HP            Notebook    6    2.19    12224000.0            0    0
# 1302    Asus            Notebook    4    2.20     5904000.0            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 699        HP            Notebook    4    2.10            0    1  141.211998
# 419    Lenovo           Ultrabook    8    1.75            0    1  157.350512
# 997      Acer            Notebook    4    2.40            0    0  100.454670
# 502    Lenovo  2 in 1 Convertible    8    1.40            1    1  158.482530
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1192       HP            Notebook    4    1.86            0    0  100.454670
#
# ...
